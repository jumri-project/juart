# %%
# %matplotlib widget

import matplotlib.pyplot as plt
import numpy as np
from juart.ellipsoid_phantoms.ellipsoids import SheppLogan

# %% [markdown]
# # Create 2D SheppLogan Phantom

# %%
fov = [0.2, 0.2]
matrix = [256, 256]

# %%
sl = SheppLogan(fov=fov, matrix=matrix)
img = sl.get_object()

# %%
plt.figure()
plt.imshow(img[..., 0], cmap="gray")
plt.title("2D Shepp-Logan Phantom")
plt.axis("off")
plt.tight_layout()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Add coil to phantom

# %%
sl.add_coil()

# %%
plt.figure()
plt.imshow(img[..., 0], cmap="gray")
plt.scatter(
    sl.coil.coil_channel_positions[:, 0] * matrix[0] + matrix[0] // 2,
    sl.coil.coil_channel_positions[:, 1] * matrix[1] + matrix[1] // 2,
    c="red",
    s=50,
    label="Coils",
)
plt.title("2D Shepp-Logan Phantom")
plt.axis("off")
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
img = sl.get_object()

# %%
plt.figure(figsize=(10, 3))
plt.imshow(np.abs(img.reshape(-1, matrix[1]).T))
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_130772/1108888704.py:2: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   plt.imshow(np.abs(img.reshape(-1, matrix[1]).T))
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
